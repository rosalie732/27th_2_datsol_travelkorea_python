# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
plt.rc('font', family='NanumBarunGothic')

# %%
df_s1 = pd.read_csv("/content/seoul_food.csv")
df_s2 = pd.read_csv("/content/seoul_place.csv")
df_cb1 = pd.read_csv("/content/chungbuk_food.csv")
df_cb2 = pd.read_csv("/content/chungbuk_place.csv")
df_cn1 = pd.read_csv("/content/chungnam_food.csv")
df_cn2 = pd.read_csv("/content/chungnam_place.csv")
df_d1 = pd.read_csv("/content/daejeon_food.csv")
df_d2 = pd.read_csv("/content/daejeon_place.csv")
df_g1 = pd.read_csv("/content/gwangju_food.csv")
df_g2 = pd.read_csv("/content/gwangju_place.csv")
df_i1 = pd.read_csv("/content/incheon_food.csv")
df_i2 = pd.read_csv("/content/incheon_place.csv")

# %% [markdown]
# #서울 맛집

# %%
df_s1.head()
# Out:
#    순위       업소명                   주소     분류  외지인 검색 수
# 0   1  신당동떡볶이타운                서울 중구  음식점기타     70023
# 1   2     우래옥본점     서울 중구 창경궁로 62-29     한식     48777
# 2   3  소문난성수감자탕     서울 성동구 연무장길 45-0     한식     43026
# 3   4      또순이네  서울 영등포구 선유로47길 16-0     한식     39103
# 4   5  삼청동수제비본점     서울 종로구 삼청로 101-1     한식     38124

# %%
#결측치 확인
df_s1.isnull().sum()
# Out:
# 순위          0
# 업소명         0
# 주소          0
# 분류          0
# 외지인 검색 수    0
# dtype: int64

# %%
df_s1['분류'].replace(['한식'],1, inplace=True)
df_s1['분류'].replace(['외국식'],2, inplace=True)
df_s1['분류'].replace(['전문음식'],3, inplace=True)
df_s1['분류'].replace(['간이음식'],4, inplace=True)
df_s1['분류'].replace(['카페/찻집'],5, inplace=True)
df_s1['분류'].replace(['음식점기타'],6, inplace=True)

# %%
df_counts1 = df_s1["분류"].value_counts()
df_counts1.plot.bar()

# %% [markdown]
# #서울 관광지

# %%
df_s2.head()
# Out:
#    순위         관광지명                  주소    분류  외지인 검색 수
# 0   1    김포국제공항국내선    서울 강서구 하늘길 111-0  교통시설   1496950
# 1   2        더현대서울  서울 영등포구 여의대로 108-0   백화점    800966
# 2   3    신세계백화점강남점   서울 서초구 신반포로 176-0   백화점    609111
# 3   4          코엑스   서울 강남구 영동대로 513-0  전시시설    566896
# 4   5  가락동농수산물도매시장   서울 송파구 양재대로 932-0    시장    413410

# %%
#결측치 확인
df_s2.isnull().sum()
# Out:
# 순위          0
# 관광지명        0
# 주소          0
# 분류          0
# 외지인 검색 수    0
# dtype: int64

# %%
df_s2['분류'].replace(['교통시설'],1, inplace=True)
df_s2['분류'].replace(['백화점', '쇼핑몰'],2, inplace=True)
df_s2['분류'].replace(['랜드마크관광', '기타문화관광지', '복합관광시설', '기타관광', '웰니스관광'],3, inplace=True)
df_s2['분류'].replace(['전시시설', '공연시설'],4, inplace=True)
df_s2['분류'].replace(['레저스포츠시설', '육상레저스포츠', '기타레저스포츠', '캠핑'],5, inplace=True)
df_s2['분류'].replace(['호텔', '콘도미니엄', '모텔'],6, inplace=True)
df_s2['분류'].replace(['시장', '대형마트'],7, inplace=True)
df_s2['분류'].replace(['도시공원', '테마공원'],8, inplace=True)
df_s2['분류'].replace(['자연경관(하천/해양)', '자연경관(산)', '자연공원', '자연생태'],9, inplace=True)
df_s2['분류'].replace(['역사유적지', '종교성지'],10, inplace=True)
df_s2['분류'].replace(['데이트코스'],11, inplace=True)

# %%
df_counts2 = df_s2["분류"].value_counts()
df_counts2.plot.bar()

# %% [markdown]
# #충북 맛집

# %%
df_cb1.head()
# Out:
#    순위          업소명                      주소     분류  외지인 검색 수
# 0   1          카페산       충북 단양군 두산길 196-86  카페/찻집     69890
# 1   2         트리브링  충북 청주시 서원구 청남로 1388-36  카페/찻집     37959
# 2   3        게으른악어        충북 충주시 월악로 927-0  카페/찻집     20562
# 3   4         덩실분식        충북 제천시 독순로6길 5-0   간이음식     20195
# 4   5  드롭탑오송역언더패스점              충북 청주시 흥덕구  카페/찻집     19664

# %%
#결측치 확인
df_cb1.isnull().sum()
# Out:
# 순위          0
# 업소명         0
# 주소          0
# 분류          0
# 외지인 검색 수    0
# dtype: int64

# %%
df_cb1['분류'].replace(['한식'],1, inplace=True)
df_cb1['분류'].replace(['외국식'],2, inplace=True)
df_cb1['분류'].replace(['전문음식'],3, inplace=True)
df_cb1['분류'].replace(['간이음식'],4, inplace=True)
df_cb1['분류'].replace(['카페/찻집'],5, inplace=True)
df_cb1['분류'].replace(['음식점기타'],6, inplace=True)

# %%
df_countcb1 = df_cb1["분류"].value_counts()
df_countcb1.plot.bar()

# %% [markdown]
# #충북 관광지

# %%
df_cb2.head()
# Out:
#    순위      관광지명                     주소     분류  외지인 검색 수
# 0   1    청주국제공항  충북 청주시 청원구 오창대로 980-0   교통시설    302729
# 1   2     소노문단양      충북 단양군 삼봉로 187-17  콘도미니엄    113749
# 2   3    단양구경시장       충북 단양군 도전5길 31-0     시장    103653
# 3   4  현대백화점충청점  충북 청주시 흥덕구 직지대로 308-0    백화점    102477
# 4   5  청풍호반케이블카      충북 제천시 문화재길 166-0   기타관광     95451

# %%
#결측치 확인
df_cb2.isnull().sum()
# Out:
# 순위          0
# 관광지명        0
# 주소          0
# 분류          0
# 외지인 검색 수    0
# dtype: int64

# %%
df_cb2['분류'].replace(['교통시설'],1, inplace=True)
df_cb2['분류'].replace(['백화점', '쇼핑몰'],2, inplace=True)
df_cb2['분류'].replace(['랜드마크관광', '기타문화관광지', '복합관광시설', '기타관광', '웰니스관광'],3, inplace=True)
df_cb2['분류'].replace(['전시시설', '공연시설'],4, inplace=True)
df_cb2['분류'].replace(['레저스포츠시설', '육상레저스포츠', '기타레저스포츠', '캠핑'],5, inplace=True)
df_cb2['분류'].replace(['호텔', '콘도미니엄', '모텔'],6, inplace=True)
df_cb2['분류'].replace(['시장', '대형마트'],7, inplace=True)
df_cb2['분류'].replace(['도시공원', '테마공원'],8, inplace=True)
df_cb2['분류'].replace(['자연경관(하천/해양)', '자연경관(산)', '자연공원', '자연생태'],9, inplace=True)
df_cb2['분류'].replace(['역사유적지', '종교성지'],10, inplace=True)
df_cb2['분류'].replace(['데이트코스'],11, inplace=True)

# %%
df_countcb2 = df_cb2["분류"].value_counts()
df_countcb2.plot.bar()

# %% [markdown]
# #충남 맛집

# %%
df_cn1.head()
# Out:
#    순위       업소명                      주소     분류  외지인 검색 수
# 0   1  ROAD1950        충남 당진시 매산로 170-0  카페/찻집     65654
# 1   2     천북굴단지                  충남 보령시  음식점기타     54065
# 2   3    병천순대거리  충남 천안시 동남구 아우내순대길 33-0  음식점기타     51527
# 3   4  뚜쥬루빵돌가마점    충남 천안시 동남구 풍세로 706-0   간이음식     49960
# 4   5     우렁이박사          충남 당진시 샛터로 7-1     한식     37627

# %%
#결측치 확인
df_cn1.isnull().sum()
# Out:
# 순위          0
# 업소명         0
# 주소          0
# 분류          0
# 외지인 검색 수    0
# dtype: int64

# %%
df_cn1['분류'].replace(['한식'],1, inplace=True)
df_cn1['분류'].replace(['외국식'],2, inplace=True)
df_cn1['분류'].replace(['전문음식'],3, inplace=True)
df_cn1['분류'].replace(['간이음식'],4, inplace=True)
df_cn1['분류'].replace(['카페/찻집'],5, inplace=True)
df_cn1['분류'].replace(['음식점기타'],6, inplace=True)

# %%
df_countcn1 = df_cn1["분류"].value_counts()
df_countcn1.plot.bar()

# %% [markdown]
# #충남 관광지

# %%
df_cn2.head()
# Out:
#    순위         관광지명                     주소           분류  외지인 검색 수
# 0   1       대천해수욕장                 충남 보령시  자연경관(하천/해양)    370990
# 1   2       삽교호관광지     충남 당진시 삽교천3길 100-0       복합관광시설    233832
# 2   3       꽃지해수욕장     충남 태안군 꽃지해안로 400-0  자연경관(하천/해양)    170297
# 3   4  신세계백화점천안아산점    충남 천안시 동남구 만남로 43-0          백화점    167502
# 4   5   코스트코홀세일천안점  충남 천안시 서북구 3공단6로 77-0         대형마트    142159

# %%
#결측치 확인
df_cn2.isnull().sum()
# Out:
# 순위          0
# 관광지명        0
# 주소          0
# 분류          0
# 외지인 검색 수    0
# dtype: int64

# %%
df_cn2['분류'].replace(['교통시설'],1, inplace=True)
df_cn2['분류'].replace(['백화점', '쇼핑몰'],2, inplace=True)
df_cn2['분류'].replace(['랜드마크관광', '기타문화관광지', '복합관광시설', '기타관광', '웰니스관광'],3, inplace=True)
df_cn2['분류'].replace(['전시시설', '공연시설'],4, inplace=True)
df_cn2['분류'].replace(['레저스포츠시설', '육상레저스포츠', '기타레저스포츠', '캠핑'],5, inplace=True)
df_cn2['분류'].replace(['호텔', '콘도미니엄', '모텔'],6, inplace=True)
df_cn2['분류'].replace(['시장', '대형마트'],7, inplace=True)
df_cn2['분류'].replace(['도시공원', '테마공원'],8, inplace=True)
df_cn2['분류'].replace(['자연경관(하천/해양)', '자연경관(산)', '자연공원', '자연생태'],9, inplace=True)
df_cn2['분류'].replace(['역사유적지', '종교성지'],10, inplace=True)
df_cn2['분류'].replace(['데이트코스'],11, inplace=True)

# %%
df_countcn2 = df_cn2["분류"].value_counts()
df_countcn2.plot.bar()

# %% [markdown]
# #대전 맛집

# %%
df_d1.head()
# Out:
#    순위      업소명                    주소     분류  외지인 검색 수
# 0   1    성심당본관   대전 중구 대종로480번길 15-0   간이음식    109004
# 1   2  성심당DCC점     대전 유성구 엑스포로 107-0   간이음식     61968
# 2   3  태평소국밥본관  대전 유성구 온천동로65번길 50-0     한식     35648
# 3   4    카페팡시온  대전 동구 회남로275번길 227-0  카페/찻집     25852
# 4   5  오문창순대국밥    대전 대덕구 한밭대로 1153-0     한식     23549

# %%
#결측치 확인
df_d1.isnull().sum()
# Out:
# 순위          0
# 업소명         0
# 주소          0
# 분류          0
# 외지인 검색 수    0
# dtype: int64

# %%
df_d1['분류'].replace(['한식'],1, inplace=True)
df_d1['분류'].replace(['외국식'],2, inplace=True)
df_d1['분류'].replace(['전문음식'],3, inplace=True)
df_d1['분류'].replace(['간이음식'],4, inplace=True)
df_d1['분류'].replace(['카페/찻집'],5, inplace=True)
df_d1['분류'].replace(['음식점기타'],6, inplace=True)

# %%
df_countd1 = df_d1["분류"].value_counts()
df_countd1.plot.bar()

# %% [markdown]
# #대전 관광지

# %%
df_d2.head()
# Out:
#    순위          관광지명                주소    분류  외지인 검색 수
# 0   1   신세계백화점대전신세계   대전 유성구 엑스포로 1-0   백화점    398445
# 1   2  갤러리아백화점타임월드점  대전 서구 대덕대로 211-0   백화점    189090
# 2   3    코스트코홀세일대전점    대전 중구 오류로 41-0  대형마트    109341
# 3   4   이마트트레이더스월평점  대전 서구 한밭대로 580-0  대형마트    105332
# 4   5      롯데백화점대전점   대전 서구 계룡로 598-0   백화점     98000

# %%
#결측치 확인
df_d2.isnull().sum()
# Out:
# 순위          0
# 관광지명        0
# 주소          0
# 분류          0
# 외지인 검색 수    0
# dtype: int64

# %%
df_d2['분류'].replace(['교통시설'],1, inplace=True)
df_d2['분류'].replace(['백화점', '쇼핑몰'],2, inplace=True)
df_d2['분류'].replace(['랜드마크관광', '기타문화관광지', '복합관광시설', '기타관광', '웰니스관광'],3, inplace=True)
df_d2['분류'].replace(['전시시설', '공연시설'],4, inplace=True)
df_d2['분류'].replace(['레저스포츠시설', '육상레저스포츠', '기타레저스포츠', '캠핑'],5, inplace=True)
df_d2['분류'].replace(['호텔', '콘도미니엄', '모텔'],6, inplace=True)
df_d2['분류'].replace(['시장', '대형마트'],7, inplace=True)
df_d2['분류'].replace(['도시공원', '테마공원'],8, inplace=True)
df_d2['분류'].replace(['자연경관(하천/해양)', '자연경관(산)', '자연공원', '자연생태'],9, inplace=True)
df_d2['분류'].replace(['역사유적지', '종교성지'],10, inplace=True)
df_d2['분류'].replace(['데이트코스'],11, inplace=True)

# %%
df_countd2 = df_d2["분류"].value_counts()
df_countd2.plot.bar()

# %% [markdown]
# #광주 맛집

# %%
df_g1.head()
# Out:
#    순위        업소명                   주소     분류  외지인 검색 수
# 0   1  퍼니스카페앤라운지    광주 서구 천변좌하로 192-0  카페/찻집     21315
# 1   2       세컨드원  광주 광산구 임방울대로 611-25  카페/찻집     12121
# 2   3        맥문동       광주 서구 마륵로 24-0   전문음식     11558
# 3   4      영미오리탕      광주 북구 경양로 126-0     한식     11105
# 4   5     명화식육식당     광주 광산구 평동로 421-0     한식     10791

# %%
#결측치 확인
df_g1.isnull().sum()
# Out:
# 순위          0
# 업소명         0
# 주소          0
# 분류          0
# 외지인 검색 수    0
# dtype: int64

# %%
df_g1['분류'].replace(['한식'],1, inplace=True)
df_g1['분류'].replace(['외국식'],2, inplace=True)
df_g1['분류'].replace(['전문음식'],3, inplace=True)
df_g1['분류'].replace(['간이음식'],4, inplace=True)
df_g1['분류'].replace(['카페/찻집'],5, inplace=True)
df_g1['분류'].replace(['음식점기타'],6, inplace=True)

# %%
df_countg1 = df_g1["분류"].value_counts()
df_countg1.plot.bar()

# %% [markdown]
# #광주 관광지

# %%
df_g2.head()
# Out:
#    순위       관광지명                  주소    분류  외지인 검색 수
# 0   1  신세계백화점광주점    광주 서구 무진대로 932-0   백화점    131867
# 1   2       광주공항  광주 광산구 상무대로 420-25  교통시설    104608
# 2   3   롯데백화점광주점     광주 동구 독립로 268-0   백화점     81424
# 3   4   김대중컨벤션센터    광주 서구 상무누리로 30-0  전시시설     67597
# 4   5     이마트광주점     광주 서구 죽봉대로 61-0  대형마트     56881

# %%
#결측치 확인
df_g2.isnull().sum()
# Out:
# 순위          0
# 관광지명        0
# 주소          0
# 분류          0
# 외지인 검색 수    0
# dtype: int64

# %%
df_g2['분류'].replace(['교통시설'],1, inplace=True)
df_g2['분류'].replace(['백화점', '쇼핑몰'],2, inplace=True)
df_g2['분류'].replace(['랜드마크관광', '기타문화관광지', '복합관광시설', '기타관광', '웰니스관광'],3, inplace=True)
df_g2['분류'].replace(['전시시설', '공연시설'],4, inplace=True)
df_g2['분류'].replace(['레저스포츠시설', '육상레저스포츠', '기타레저스포츠', '캠핑'],5, inplace=True)
df_g2['분류'].replace(['호텔', '콘도미니엄', '모텔'],6, inplace=True)
df_g2['분류'].replace(['시장', '대형마트'],7, inplace=True)
df_g2['분류'].replace(['도시공원', '테마공원'],8, inplace=True)
df_g2['분류'].replace(['자연경관(하천/해양)', '자연경관(산)', '자연공원', '자연생태'],9, inplace=True)
df_g2['분류'].replace(['역사유적지', '종교성지'],10, inplace=True)
df_g2['분류'].replace(['데이트코스'],11, inplace=True)

# %%
df_countg2 = df_g2["분류"].value_counts()
df_countg2.plot.bar()

# %% [markdown]
# #인천 맛집

# %%
df_i1.head()
# Out:
#    순위          업소명                     주소     분류  외지인 검색 수
# 0   1         조양방직    인천 강화군 향나무길5번길 12-0  카페/찻집     94319
# 1   2  포레스트아웃팅스송도점       인천 연수구 청량로 145-0  카페/찻집     89540
# 2   3        차이나타운  인천 중구 차이나타운로44번길 13-2  음식점기타     80302
# 3   4          뻘다방        인천 옹진군 선재로 55-0  카페/찻집     65771
# 4   5       마시안제빵소       인천 중구 마시란로 155-0   간이음식     47152

# %%
#결측치 확인
df_i1.isnull().sum()
# Out:
# 순위          0
# 업소명         0
# 주소          0
# 분류          0
# 외지인 검색 수    0
# dtype: int64

# %%
df_i1['분류'].replace(['한식'],1, inplace=True)
df_i1['분류'].replace(['외국식'],2, inplace=True)
df_i1['분류'].replace(['전문음식'],3, inplace=True)
df_i1['분류'].replace(['간이음식'],4, inplace=True)
df_i1['분류'].replace(['카페/찻집'],5, inplace=True)
df_i1['분류'].replace(['음식점기타'],6, inplace=True)

# %%
df_counti1 = df_i1["분류"].value_counts()
df_counti1.plot.bar()

# %% [markdown]
# #인천 관광지

# %%
df_i2.head()
# Out:
#    순위           관광지명                   주소           분류  외지인 검색 수
# 0   1  인천국제공항제1여객터미널      인천 중구 공항로 272-0         교통시설   1028721
# 1   2  인천국제공항제2여객터미널  인천 중구 제2터미널대로 446-0         교통시설    596360
# 2   3            월미도                인천 중구  자연경관(하천/해양)    429547
# 3   4        을왕리해수욕장       인천 중구 을왕로 52-0  자연경관(하천/해양)    396471
# 4   5       롯데백화점인천점     인천 미추홀구 연남로 35-0          백화점    314229

# %%
#결측치 확인
df_i2.isnull().sum()
# Out:
# 순위          0
# 관광지명        0
# 주소          0
# 분류          0
# 외지인 검색 수    0
# dtype: int64

# %%
df_i2['분류'].replace(['교통시설'],1, inplace=True)
df_i2['분류'].replace(['백화점', '쇼핑몰'],2, inplace=True)
df_i2['분류'].replace(['랜드마크관광', '기타문화관광지', '복합관광시설', '기타관광', '웰니스관광'],3, inplace=True)
df_i2['분류'].replace(['전시시설', '공연시설'],4, inplace=True)
df_i2['분류'].replace(['레저스포츠시설', '육상레저스포츠', '기타레저스포츠', '캠핑'],5, inplace=True)
df_i2['분류'].replace(['호텔', '콘도미니엄', '모텔'],6, inplace=True)
df_i2['분류'].replace(['시장', '대형마트'],7, inplace=True)
df_i2['분류'].replace(['도시공원', '테마공원'],8, inplace=True)
df_i2['분류'].replace(['자연경관(하천/해양)', '자연경관(산)', '자연공원', '자연생태'],9, inplace=True)
df_i2['분류'].replace(['역사유적지', '종교성지'],10, inplace=True)
df_i2['분류'].replace(['데이트코스'],11, inplace=True)

# %%
df_counti2 = df_i2["분류"].value_counts()
df_counti2.plot.bar()

# %% [markdown]
# #데이터 시각화

# %%
# violin plot
#import seaborn as sns
#sns.violinplot(x="분류", y="외지인 검색 수", data=df)
#plt.show()

# %%
# box plot
#sns.boxplot(x="분류", y="외지인 검색 수", data=df)
#plt.show()

# %% [markdown]
# **<관광지>**
#
# 부산_관광지

# %%
df = pd.read_csv("/content/drive/MyDrive/solux/BK_tourist.csv", encoding='cp949')

# %%
df.head()
# Out:
#    순위         관광지명                  주소    분류  외지인 검색 수
# 0   1  신세계백화점센텀시티점  부산 해운대구 센텀남대로 35-0   백화점    439552
# 1   2    김해공항국내선청사  부산 강서구 공항진입로 108-0  교통시설    411624
# 2   3    롯데백화점부산본점  부산 부산진구 가야대로 772-0   백화점    311933
# 3   4       김해국제공항  부산 강서구 공항진입로 108-0  교통시설    240605
# 4   5   코스트코홀세일부산점    부산 수영구 구락로 137-0  대형마트    239333

# %%
#결측치 확인
df.isnull().sum()
# Out:
# 순위          0
# 관광지명        0
# 주소          0
# 분류          0
# 외지인 검색 수    0
# dtype: int64

# %%
df['분류'].replace(['교통시설'],1, inplace=True)
df['분류'].replace(['백화점', '쇼핑몰'],2, inplace=True)
df['분류'].replace(['랜드마크관광', '기타문화관광지', '복합관광시설', '기타관광', '웰니스관광'],3, inplace=True)
df['분류'].replace(['전시시설', '공연시설'],4, inplace=True)
df['분류'].replace(['레저스포츠시설', '육상레저스포츠', '수상레저스포츠', '기타레저스포츠', '캠핑'],5, inplace=True)
df['분류'].replace(['호텔', '콘도미니엄', '모텔'],6, inplace=True)
df['분류'].replace(['시장', '대형마트'],7, inplace=True)
df['분류'].replace(['도시공원', '테마공원'],8, inplace=True)
df['분류'].replace(['자연경관(하천/해양)', '자연경관(산)', '자연공원', '자연생태'],9, inplace=True)
df['분류'].replace(['역사유적지', '종교성지'],10, inplace=True)
df['분류'].replace(['데이트코스'],11, inplace=True)

# %%
plt.rc('font', family='NanumBarunGothic')

# %%
df_count = df["분류"].value_counts()
df_count.plot.bar()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# 부산 맛집

# %%
df = pd.read_csv("/content/drive/MyDrive/solux/BS_food.csv", encoding='cp949')

# %%
df.head()
# Out:
#    순위         업소명                      주소     분류  합산 검색 수
# 0   1        칠암사계        부산 기장군 칠암1길 7-10  카페/찻집   101466
# 1   2      웨이브온커피       부산 기장군 해맞이로 286-0  카페/찻집    69720
# 2   3  피아크카페앤베이커리   부산 영도구 해양로195번길 180-0  카페/찻집    61764
# 3   4    해운대암소갈비집  부산 해운대구 중동2로10번길 32-10     한식    50008
# 4   5        바릇식당        부산 기장군 문오성길 61-0   전문음식    34530

# %%
#결측치 확인
df.isnull().sum()
# Out:
# 순위         0
# 업소명        0
# 주소         0
# 분류         0
# 합산 검색 수    0
# dtype: int64

# %%
df['분류'].replace(['한식'],1, inplace=True)
df['분류'].replace(['외국식'],2, inplace=True)
df['분류'].replace(['전문음식'],3, inplace=True)
df['분류'].replace(['간이음식' ],4, inplace=True)
df['분류'].replace(['카페/찻집' ],5, inplace=True)

# %%
plt.rc('font', family='NanumBarunGothic')

# %%
df_count = df["분류"].value_counts()
df_count.plot.bar()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# 울산

# %% [markdown]
# 울산_관광지

# %%
df = pd.read_csv("/content/drive/MyDrive/solux/US_tourist.csv", encoding='cp949')

# %%
df.head()
# Out:
#    순위        관광지명                    주소    분류  외지인 검색 수
# 0   1         간절곶                울산 울주군  기타관광    106419
# 1   2  코스트코홀세일울산점     울산 북구 진장유통로 78-12  대형마트     99799
# 2   3    현대백화점울산점       울산 남구 삼산로 261-0   백화점     81167
# 3   4       대왕암공원        울산 동구 등대로 95-0  도시공원     80048
# 4   5     태화강국가정원  울산 중구 태화강국가정원길 154-0  도시공원     68106

# %%
#결측치 확인
df.isnull().sum()
# Out:
# 순위          0
# 관광지명        0
# 주소          0
# 분류          0
# 외지인 검색 수    0
# dtype: int64

# %%
df['분류'].replace(['교통시설'],1, inplace=True)
df['분류'].replace(['백화점', '쇼핑몰'],2, inplace=True)
df['분류'].replace(['랜드마크관광', '기타문화관광지', '복합관광시설', '기타관광', '웰니스관광'],3, inplace=True)
df['분류'].replace(['전시시설', '공연시설'],4, inplace=True)
df['분류'].replace(['레저스포츠시설', '육상레저스포츠', '수상레저스포츠', '기타레저스포츠', '캠핑'],5, inplace=True)
df['분류'].replace(['호텔', '콘도미니엄', '모텔','펜션/민박'],6, inplace=True)
df['분류'].replace(['시장', '대형마트'],7, inplace=True)
df['분류'].replace(['도시공원', '테마공원'],8, inplace=True)
df['분류'].replace(['자연경관(하천/해양)', '자연경관(산)', '자연공원', '자연생태', '농/산/어촌체험'],9, inplace=True)
df['분류'].replace(['역사유적지', '종교성지', '역사유물'],10, inplace=True)
df['분류'].replace(['데이트코스'],11, inplace=True)

# %%
df_count = df["분류"].value_counts()
df_count.plot.bar()

# %% [markdown]
# 울산_맛집

# %%
df = pd.read_csv("/content/drive/MyDrive/solux/US_food.csv", encoding='cp949')

# %%
df.head()
# Out:
#    순위       업소명                  주소     분류  합산 검색 수
# 0   1  언양기와집불고기     울산 울주군 헌양길 86-0     한식    53177
# 1   2    그릿비서생점   울산 울주군 신암해안1길 4-0  카페/찻집    33774
# 2   3     나사리식당   울산 울주군 나사해안길 15-0     한식    18946
# 3   4     라메르판지     울산 북구 판지1길 30-0  카페/찻집    17559
# 4   5       AOP  울산 울주군 해맞이로 1097-2  카페/찻집    15581

# %%
#결측치 확인
df.isnull().sum()
# Out:
# 순위         0
# 업소명        0
# 주소         0
# 분류         0
# 합산 검색 수    0
# dtype: int64

# %%
df['분류'].replace(['한식'],1, inplace=True)
df['분류'].replace(['외국식'],2, inplace=True)
df['분류'].replace(['전문음식'],3, inplace=True)
df['분류'].replace(['간이음식' ],4, inplace=True)
df['분류'].replace(['카페/찻집' ],5, inplace=True)
df['분류'].replace(['음식점기타' ],6, inplace=True)

# %%
df_count = df["분류"].value_counts()
df_count.plot.bar()

# %% [markdown]
# 경남

# %% [markdown]
# 경남_관광지

# %%
df = pd.read_csv("/content/drive/MyDrive/solux/KN_tourist.csv", encoding='cp949')

# %%
df.head()
# Out:
#    순위      관광지명                   주소       분류  외지인 검색 수
# 0   1  통영중앙전통시장  경남 통영시 중앙시장1길 14-16       시장    191998
# 1   2      독일마을      경남 남해군 독일로 92-0     기타관광    148483
# 2   3     바람의언덕               경남 거제시  기타문화관광지    132168
# 3   4       통도사    경남 양산시 통도사로 108-0     종교성지    128865
# 4   5     소노캄거제   경남 거제시 거제대로 2660-0    콘도미니엄    110300

# %%
#결측치 확인
df.isnull().sum()
# Out:
# 순위          0
# 관광지명        0
# 주소          0
# 분류          0
# 외지인 검색 수    0
# dtype: int64

# %%
df['분류'].replace(['교통시설'],1, inplace=True)
df['분류'].replace(['백화점', '쇼핑몰'],2, inplace=True)
df['분류'].replace(['랜드마크관광', '기타문화관광지', '복합관광시설', '기타관광', '웰니스관광'],3, inplace=True)
df['분류'].replace(['전시시설', '공연시설'],4, inplace=True)
df['분류'].replace(['레저스포츠시설', '육상레저스포츠', '수상레저스포츠', '기타레저스포츠', '캠핑'],5, inplace=True)
df['분류'].replace(['호텔', '콘도미니엄', '모텔','펜션/민박'],6, inplace=True)
df['분류'].replace(['시장', '대형마트'],7, inplace=True)
df['분류'].replace(['도시공원', '테마공원'],8, inplace=True)
df['분류'].replace(['자연경관(하천/해양)', '자연경관(산)', '자연공원', '자연생태', '농/산/어촌체험'],9, inplace=True)
df['분류'].replace(['역사유적지', '종교성지', '역사유물'],10, inplace=True)
df['분류'].replace(['데이트코스'],11, inplace=True)

# %%
df_count = df["분류"].value_counts()
df_count.plot.bar()

# %% [markdown]
# 경남_맛집

# %%
df = pd.read_csv("/content/drive/MyDrive/solux/KN_food.csv", encoding='cp949')

# %%
df.head()
# Out:
#    순위          업소명                    주소     분류  합산 검색 수
# 0   1  투썸플레이스창원귀산점  경남 창원시 성산구 삼귀로 167-0  카페/찻집    65720
# 1   2        하연옥본점   경남 진주시 진주대로 1317-20     한식    44805
# 2   3        동부회센터    경남 창원시 진해구 천자로 5-0   전문음식    29792
# 3   4         온더선셋       경남 거제시 성포로 65-0  카페/찻집    29455
# 4   5  스타벅스창원마창대교점  경남 창원시 성산구 삼귀로 159-0  카페/찻집    29389

# %%
#결측치 확인
df.isnull().sum()
# Out:
# 순위         0
# 업소명        0
# 주소         0
# 분류         0
# 합산 검색 수    0
# dtype: int64

# %%
df['분류'].replace(['한식'],1, inplace=True)
df['분류'].replace(['외국식'],2, inplace=True)
df['분류'].replace(['전문음식'],3, inplace=True)
df['분류'].replace(['간이음식' ],4, inplace=True)
df['분류'].replace(['카페/찻집' ],5, inplace=True)
df['분류'].replace(['음식점기타' ],6, inplace=True)

# %%
df_count = df["분류"].value_counts()
df_count.plot.bar()

# %% [markdown]
# 대구

# %% [markdown]
# 대구_관광지

# %%
df = pd.read_csv("/content/drive/MyDrive/solux/DK_tourist.csv", encoding='cp949')

# %%
df.head()
# Out:
#    순위            관광지명                  주소    분류  외지인 검색 수
# 0   1       신세계백화점대구점     대구 동구 동부로 149-0   백화점    394786
# 1   2        현대백화점대구점  대구 중구 달구벌대로 2077-0   백화점    150269
# 2   3            서문시장   대구 중구 큰장로26길 45-0    시장    144942
# 3   4      코스트코홀세일대구점      대구 북구 검단로 97-0  대형마트    140525
# 4   5  코스트코홀세일대구혁신도시점      대구 동구 첨단로 10-0  대형마트    130230

# %%
#결측치 확인
df.isnull().sum()
# Out:
# 순위          0
# 관광지명        0
# 주소          0
# 분류          0
# 외지인 검색 수    0
# dtype: int64

# %%
df['분류'].replace(['교통시설'],1, inplace=True)
df['분류'].replace(['백화점', '쇼핑몰'],2, inplace=True)
df['분류'].replace(['랜드마크관광', '기타문화관광지', '복합관광시설', '기타관광', '웰니스관광'],3, inplace=True)
df['분류'].replace(['전시시설', '공연시설'],4, inplace=True)
df['분류'].replace(['레저스포츠시설', '육상레저스포츠', '수상레저스포츠', '기타레저스포츠', '캠핑'],5, inplace=True)
df['분류'].replace(['호텔', '콘도미니엄', '모텔','펜션/민박'],6, inplace=True)
df['분류'].replace(['시장', '대형마트'],7, inplace=True)
df['분류'].replace(['도시공원', '테마공원'],8, inplace=True)
df['분류'].replace(['자연경관(하천/해양)', '자연경관(산)', '자연공원', '자연생태', '농/산/어촌체험'],9, inplace=True)
df['분류'].replace(['역사유적지', '종교성지', '역사유물'],10, inplace=True)
df['분류'].replace(['데이트코스'],11, inplace=True)

# %%
df_count = df["분류"].value_counts()
df_count.plot.bar()

# %% [markdown]
# 대구_맛집

# %%
df = pd.read_csv("/content/drive/MyDrive/solux/DK_food.csv", encoding='cp949')

# %%
df.head()
# Out:
#    순위         업소명                 주소     분류  합산 검색 수
# 0   1        대덕식당  대구 남구 앞산순환로 443-0     한식    22226
# 1   2  바르미스시뷔페두산점    대구 수성구 무학로 78-0    외국식    20956
# 2   3     룰리커피가창점    대구 달성군 우록길 76-0  카페/찻집    20191
# 3   4        룰리커피   대구 수성구 고모로 188-0  카페/찻집    19049
# 4   5        아눅앞산  대구 남구 앞산순환로 459-0  카페/찻집    18574

# %%
#결측치 확인
df.isnull().sum()
# Out:
# 순위         0
# 업소명        0
# 주소         0
# 분류         0
# 합산 검색 수    0
# dtype: int64

# %%
df['분류'].replace(['한식'],1, inplace=True)
df['분류'].replace(['외국식'],2, inplace=True)
df['분류'].replace(['전문음식'],3, inplace=True)
df['분류'].replace(['간이음식' ],4, inplace=True)
df['분류'].replace(['카페/찻집' ],5, inplace=True)
df['분류'].replace(['음식점기타' ],6, inplace=True)

# %%
df_count = df["분류"].value_counts()
df_count.plot.bar()

# %% [markdown]
# 전남

# %% [markdown]
# 전남_관광지

# %%
df = pd.read_csv("/content/drive/MyDrive/solux/JN_tourist.csv", encoding='cp949')

# %%
df.head()
# Out:
#    순위       관광지명                   주소           분류  외지인 검색 수
# 0   1      쏠비치진도     전남 진도군 송군길 30-40        콘도미니엄    144613
# 1   2        죽녹원    전남 담양군 죽녹원로 119-0         자연공원    141804
# 2   3        오동도    전남 여수시 오동도로 222-0  자연경관(하천/해양)    113978
# 3   4    순천만국가정원  전남 순천시 국가정원1호길 47-0         기타관광    112026
# 4   5  완도항여객선터미널   전남 완도군 장보고대로 339-0         교통시설    109122

# %%
#결측치 확인
df.isnull().sum()
# Out:
# 순위          0
# 관광지명        0
# 주소          0
# 분류          0
# 외지인 검색 수    0
# dtype: int64

# %%
df['분류'].replace(['교통시설'],1, inplace=True)
df['분류'].replace(['백화점', '쇼핑몰'],2, inplace=True)
df['분류'].replace(['랜드마크관광', '기타문화관광지', '복합관광시설', '기타관광', '웰니스관광'],3, inplace=True)
df['분류'].replace(['전시시설', '공연시설'],4, inplace=True)
df['분류'].replace(['레저스포츠시설', '육상레저스포츠', '수상레저스포츠', '기타레저스포츠', '캠핑'],5, inplace=True)
df['분류'].replace(['호텔', '콘도미니엄', '모텔','펜션/민박'],6, inplace=True)
df['분류'].replace(['시장', '대형마트'],7, inplace=True)
df['분류'].replace(['도시공원', '테마공원'],8, inplace=True)
df['분류'].replace(['자연경관(하천/해양)', '자연경관(산)', '자연공원', '자연생태', '농/산/어촌체험'],9, inplace=True)
df['분류'].replace(['역사유적지', '종교성지', '역사유물'],10, inplace=True)
df['분류'].replace(['데이트코스'],11, inplace=True)

# %%
df_count = df["분류"].value_counts()
df_count.plot.bar()

# %% [markdown]
# 전남_맛집

# %%
df = pd.read_csv("/content/drive/MyDrive/solux/JN_food.csv", encoding='cp949')

# %%
df.head()
# Out:
#    순위         업소명                  주소     분류  합산 검색 수
# 0   1     나주곰탕하얀집     전남 나주시 금성관길 6-1     한식    65318
# 1   2         모이핀    전남 여수시 무술목길 50-0  카페/찻집    58872
# 2   3     꽃돌게장1번가    전남 여수시 봉산2로 36-0   전문음식    53896
# 3   4      여수명동게장  전남 여수시 봉산남4길 23-26   전문음식    47603
# 4   5  쌍교숯불갈비담양본점   전남 담양군 송강정로 212-0     한식    47000

# %%
#결측치 확인
df.isnull().sum()
# Out:
# 순위         0
# 업소명        0
# 주소         0
# 분류         0
# 합산 검색 수    0
# dtype: int64

# %%
df['분류'].replace(['한식'],1, inplace=True)
df['분류'].replace(['외국식'],2, inplace=True)
df['분류'].replace(['전문음식'],3, inplace=True)
df['분류'].replace(['간이음식' ],4, inplace=True)
df['분류'].replace(['카페/찻집' ],5, inplace=True)
df['분류'].replace(['음식점기타' ],6, inplace=True)

# %%
df_count = df["분류"].value_counts()
df_count.plot.bar()
